# %% [markdown]
# #About Dataset
# salaries dataset generally provides information about the employees of an organization in relation to their compensation. It typically includes details such as how much each employee is paid (their salary), their job titles, the departments they work in, and possibly additional information like their level of experience, education, and employment history within the organization.

# %%
Nour AlHuda ALadal

# %% [markdown]
# # Features
# - 'Id'
# - 'EmployeeName'
# - 'JobTitle'
# - 'BasePay'
# - 'OvertimePay'
# - 'OtherPay'
# - 'Benefits'
# - 'TotalPay' -> salary
# - 'TotalPayBenefits'
# - 'Year'
# - 'Notes'
# - 'Agency'
# - 'Status'

# %% [markdown]
# # Tasks
#
# 1. **Basic Data Exploration**: Identify the number of rows and columns in the dataset, determine the data types of each column, and check for missing values in each column.
#
# 2. **Descriptive Statistics**: Calculate basic statistics mean, median, mode, minimum, and maximum salary, determine the range of salaries, and find the standard deviation.
#
# 3. **Data Cleaning**: Handle missing data by suitable method with explain why you use it.
#
# 4. **Basic Data Visualization**: Create histograms or bar charts to visualize the distribution of salaries, and use pie charts to represent the proportion of employees in different departments.
#
# 5. **Grouped Analysis**: Group the data by one or more columns and calculate summary statistics for each group, and compare the average salaries across different groups.
#
# 6. **Simple Correlation Analysis**: Identify any correlation between salary and another numerical column, and plot a scatter plot to visualize the relationship.
#
# 8. **Summary of Insights**: Write a brief report summarizing the findings and insights from the analyses.

# %% [markdown]
# # Very Important Note
# There is no fixed or singular solution for this assignment, so if anything is not clear, please do what you understand and provide an explanation.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Load your dataset
data = pd.read_csv('Salaries.csv')
data.head(10)
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# ...

# %%
##question number 1
print("name's columns :",data.columns)
print("Num of rows and columns:", data.shape)
print("Data types of each column:\n", data.dtypes)
# القيم الفارغة
print("Missing values in each column:\n", data.isnull().sum())
# Out:
# name's columns : Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')
# Num of rows and columns: (148654, 13)
# Data types of each column:
#  Id                    int64
# EmployeeName         object
# JobTitle             object
# BasePay             float64
# OvertimePay         float64
# OtherPay            float64
# Benefits            float64
# TotalPay            float64
# TotalPayBenefits    float64
# Year                  int64
# Notes               float64
# Agency               object
# Status              float64
# dtype: object
# Missing values in each column:
#  Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                609
# OvertimePay              4
# OtherPay                 4
# Benefits             36163
# TotalPay                 0
# TotalPayBenefits         0
# ...

# %%
##question number 2
# الإحصائيات الأساسية لعمود الرواتب
salary_column = df['BasePay']

median = salary_column.median()
mode = salary_column.mode().values[0]
mean = salary_column.mean()
min_1 = salary_column.min()
max_1 = salary_column.max()
salary_range = max_1 - min_1
std_dev = salary_column.std()

# طباعة النتائج
print("Mean Salary:", mean)
print("Median Salary:", median)
print("Mode Salary:", mode)
print("Minimum Salary:", min_1)
print("Maximum Salary:", max_1)
print("Salary Range:", salary_range)
print("Standard Deviation of Salary:", std_dev)
# Out:
# Mean Salary: 66325.44884050643
# Median Salary: 65007.45
# Mode Salary: 0.0
# Minimum Salary: -166.01
# Maximum Salary: 319275.01
# Salary Range: 319441.02
# Standard Deviation of Salary: 42764.63549525958

# %%
##question number 3
# تعويض القيم المفقودة بمتوسط الرواتب
data['BasePay'].fillna(median, inplace=True)

# طباعة النتائج
print("القيم المفقودة في كل عمود:\n", data.isnull().sum())
print("الإحصائيات الأساسية بعد التعويض:\n", data.describe())
# Out:
# القيم المفقودة في كل عمود:
#  Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                  0
# OvertimePay              4
# OtherPay                 4
# Benefits             36163
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              148654
# dtype: int64
# الإحصائيات الأساسية بعد التعويض:
#                    Id        BasePay    OvertimePay       OtherPay  \
# count  148654.000000  148654.000000  148650.000000  148650.000000
# mean    74327.500000   66325.448841    5066.059886    3648.767297
# std     42912.857795   42676.946745   11454.380559    8056.601866
# min         1.000000    -166.010000      -0.010000   -7058.590000
# 25%     37164.250000   33847.017500       0.000000       0.000000
# 50%     74327.500000   65092.190000       0.000000     811.270000
# ...

# %%
##question number 4
# رسم هيستوغرام لتوزيع الرواتب
plt.figure(figsize=(10, 5))
plt.hist(data['BasePay'], bins=10, color='skyblue', edgecolor='black')
plt.title('توزيع الرواتب')
plt.xlabel('الراتب')
plt.ylabel('عدد الموظفين')
plt.show()

# %%
department_counts = df['JobTitle'].value_counts()
print(department_counts)
plt.figure(figsize=(8, 8))
plt.pie(department_counts, labels=department_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Proportion of Employees in Different Departments')
plt.axis('equal')  # للحفاظ على الدائرة بشكل متساوٍ
plt.show()

# %%
#question number 5
grouped_data = data.groupby('JobTitle')

# Calculate summary statistics for each group
summary_statistics = grouped_data.describe()

# Display the summary statistics
print(summary_statistics)
# Out:
#                                                    Id                 \
#                                                 count           mean
# JobTitle
# ACCOUNT CLERK                                    83.0   25734.819277
# ACCOUNTANT                                        5.0   24159.200000
# ACCOUNTANT INTERN                                48.0   28128.833333
# ACPO,JuvP, Juv Prob (SFERS)                       1.0  135284.000000
# ACUPUNCTURIST                                     1.0   18379.000000
# ...                                               ...            ...
# X-RAY LABORATORY AIDE                            26.0   22502.076923
# X-Ray Laboratory Aide                           100.0   98890.620000
# YOUTH COMMISSION ADVISOR, BOARD OF SUPERVISORS    1.0   23392.000000
# Youth Comm Advisor                                4.0   99677.750000
# ZOO CURATOR                                       1.0   18779.000000
#
# ...

# %%
##question number 6
correlation = data['BasePay'].corr(data['OtherPay'])

# Print the correlation coefficient
print(f"Correlation between BasePay and OtherPay: {correlation}")

# Create a scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(data['OtherPay'], data['BasePay'], alpha=0.8)
plt.title('Scatter Plot: BasePay vs OtherPay')
plt.xlabel('OtherPay')
plt.ylabel('BasePay')
plt.grid(True)
plt.show()
# Out:
# Correlation between BasePay and OtherPay: 0.2837598405060683

# %%
##question number 7
         
1.          Libraries are pandas , numpy 
            
            Data has been read from the file ('Salaries.csv')
             
            The number of columns is found using   (data.columns)

            The Shape is found using   (data.shape) 

            The type of Data using   (data.dtypes)

            The type of Data using   (data.isnull().sum())




2.	     The mean of salary is found using   (mean())  

         The median of salary is found using   (median())

         The mode of salary is found using   (mode().values[0])
        
         The min of salary is found using   (min())

         The max of salary is found using   (max())
       
         The range of salary is found using   (range())

         The Standard Deviation of salary is found using   (std_dev_salary)




3.	     Missing values were handled by replacing the median using    (data['BasePay'].fillna(median, inplace=True))



4.	       Library is matplotlib.pyplot

         the histogram of salary distribution was drawn using 10bins


5.	      The data has been grouped by column     ('JobTitle')  and a separate  group has been created for each function

    
          Comprehensive statistics were applied using (grouped_data.describe())


6.	      The correlation coefficient was calculated using correlation() Then create a plot of points on the grid

# %% [markdown]
# # Good Luck!
